# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# # **Space X  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Web scraping Falcon 9 and Falcon Heavy Launches Records from Wikipedia

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# In this lab, you will be performing web scraping to collect Falcon 9 historical launch records from a Wikipedia page titled `List of Falcon 9 and Falcon Heavy launches`
#
# [https://en.wikipedia.org/wiki/List_of_Falcon\_9\_and_Falcon_Heavy_launches](https://en.wikipedia.org/wiki/List_of_Falcon\_9\_and_Falcon_Heavy_launches?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01)

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module\_1\_L2/images/Falcon9\_rocket_family.svg)

# %% [markdown]
# Falcon 9 first stage will land successfully

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/landing\_1.gif)

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/crash.gif)

# %% [markdown]
# More specifically, the launch records are stored in a HTML table shown below:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module\_1\_L2/images/falcon9-launches-wiki.png)

# %% [markdown]
# ## Objectives
#
# Web scrap Falcon 9 launch records with `BeautifulSoup`:
#
# *   Extract a Falcon 9 launch records HTML table from Wikipedia
# *   Parse the table and convert it into a Pandas data frame

# %% [markdown]
# First let's import required packages for this lab

# %%
# !pip3 install beautifulsoup4
# !pip3 install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from beautifulsoup4) (2.2.1)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from requests) (1.26.6)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from requests) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from requests) (2021.10.8)

# %%
import sys

import requests
from bs4 import BeautifulSoup
import re
import unicodedata
import pandas as pd

print('Libraries imported')
# Out:
# Libraries imported

# %% [markdown]
# and we will provide some helper functions for you to process web scraped HTML table

# %%
def date_time(table_cells):
    """
    This function returns the data and time from the HTML  table cell
    Input: the  element of a table data cell extracts extra row
    """
    return [data_time.strip() for data_time in list(table_cells.strings)][0:2]

def booster_version(table_cells):
    """
    This function returns the booster version from the HTML  table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=''.join([booster_version for i,booster_version in enumerate( table_cells.strings) if i%2==0][0:-1])
    return out

def landing_status(table_cells):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=[i for i in table_cells.strings][0]
    return out


def get_mass(table_cells):
    mass=unicodedata.normalize("NFKD", table_cells.text).strip()
    if mass:
        mass.find("kg")
        new_mass=mass[0:mass.find("kg")+2]
    else:
        new_mass=0
    return new_mass


def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    colunm_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(colunm_name.strip().isdigit()):
        colunm_name = colunm_name.strip()
        return colunm_name

# %% [markdown]
# To keep the lab tasks consistent, you will be asked to scrape the data from a snapshot of the  `List of Falcon 9 and Falcon Heavy launches` Wikipage updated on
# `9th June 2021`

# %%
static_url = "https://en.wikipedia.org/w/index.php?title=List_of_Falcon_9_and_Falcon_Heavy_launches&oldid=1027686922"

# %% [markdown]
# Next, request the HTML page from the above URL and get a `response` object

# %% [markdown]
# ### TASK 1: Request the Falcon9 Launch Wiki page from its URL

# %% [markdown]
# First, let's perform an HTTP GET method to request the Falcon9 Launch HTML page, as an HTTP response.

# %%
response = requests.get(url=static_url)
html = response.content

# %% [markdown]
# Create a `BeautifulSoup` object from the HTML `response`

# %%
soup = BeautifulSoup(html)

# %% [markdown]
# Print the page title to verify if the `BeautifulSoup` object was created properly

# %%
soup.head.title
# Out:
# <title>List of Falcon 9 and Falcon Heavy launches - Wikipedia</title>

# %% [markdown]
# ### TASK 2: Extract all column/variable names from the HTML table header

# %% [markdown]
# Next, we want to collect all relevant column names from the HTML table header

# %% [markdown]
# Let's try to find all tables on the wiki page first. If you need to refresh your memory about `BeautifulSoup`, please check the external reference link towards the end of this lab

# %%
html_tables = soup.find_all('table')

# %% [markdown]
# Starting from the third table is our target table contains the actual launch records.

# %%
# Let's print the third table and check its content
first_launch_table = html_tables[2]

# %% [markdown]
# You should able to see the columns names embedded in the table header elements `<th>` as follows:

# %% [markdown]
# ```
# <tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# ```

# %% [markdown]
# Next, we just need to iterate through the `<th>` elements and apply the provided `extract_column_from_header()` to extract column name one by one

# %%
column_names = []

for row in first_launch_table.findAll('th'):
    name = extract_column_from_header(row)
    if name is not None and len(name) > 0:
        column_names.append(name)
    

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names

# %% [markdown]
# Check the extracted column names

# %%
print(column_names)
# Out:
# ['Flight No.', 'Date and time ( )', 'Launch site', 'Payload', 'Payload mass', 'Orbit', 'Customer', 'Launch outcome']

# %% [markdown]
# ## TASK 3: Create a data frame by parsing the launch HTML tables

# %% [markdown]
# We will create an empty dictionary with keys from the extracted column names in the previous task. Later, this dictionary will be converted into a Pandas dataframe

# %%
launch_dict= dict.fromkeys(column_names)

# Remove an irrelvant column
del launch_dict['Date and time ( )']

# Let's initial the launch_dict with each value to be an empty list
launch_dict['Flight No.'] = []
launch_dict['Launch site'] = []
launch_dict['Payload'] = []
launch_dict['Payload mass'] = []
launch_dict['Orbit'] = []
launch_dict['Customer'] = []
launch_dict['Launch outcome'] = []
# Added some new columns
launch_dict['Version Booster']=[]
launch_dict['Booster landing']=[]
launch_dict['Date']=[]
launch_dict['Time']=[]

# %%
launch_dict1 = dict.fromkeys(column_names)

del launch_dict1['Date and time ( )']

launch_dict1['Flight No.']=[]
launch_dict1['Launch site']=[]
launch_dict1['Payload']=[]
launch_dict1['Payload mass']=[]
launch_dict1['Orbit']=[]
launch_dict1['Customer']=[]
launch_dict1['Launch outcome']=[]
launch_dict1['Version Booster']=[]
launch_dict1['Booster landing']=[]
launch_dict1['Date']=[]
launch_dict1['Time']=[]

# %%
extracted_row = 0

for table_number, table in enumerate(soup.find_all('table', 'wikitable plainrowheaders collapsible')):
    for rows in table.find_all('tr'):
        if rows.th:
            if rows.th.string:
                flight_number = rows.th.string.strip()
                flag = flight_number.isdigit()
            else:
                flag=False
          
            row=rows.find_all('td')
            
            if flag:
                extracted_row += 1        
                
                launch_dict1['Flight No.'].append(flight_number)
                
                datatimelist = date_time(row[0])      
                
                date = datatimelist[0].strip(',')
                launch_dict1['Date'].append(date)
                
                time = datatimelist[1].strip(',')
                launch_dict1['Time'].append(time)
                
                bv=booster_version(row[1])
                if not(bv):
                    bv=row[1].a.string
                launch_dict1['Version Booster'].append(bv)
                
                launch_site = row[2].a.string
                launch_dict1['Launch site'].append(launch_site)
                
                payload = row[3].a.string
                launch_dict1['Payload'].append(payload)
                
                payload_mass = get_mass(row[4])
                launch_dict1['Payload mass'].append(payload_mass)
                
                orbit = row[5].a.string
                launch_dict1['Orbit'].append(orbit)
                
                try:
                    launch_dict1['Customer'].append(row[6].a.string)
                except:
                    launch_dict1['Customer'].append(None)
                
                launch_outcome = list(row[7].strings)[0].strip('\n')
                launch_dict1['Launch outcome'].append(launch_outcome)
                
                booster_landing = landing_status(row[8]).strip('\n')
                launch_dict1['Booster landing'].append(booster_landing)

# %% [markdown]
# Next, we just need to fill up the `launch_dict` with launch records extracted from table rows.

# %% [markdown]
# Usually, HTML tables in Wiki pages are likely to contain unexpected annotations and other types of noises, such as reference links `B0004.1[8]`, missing values `N/A [e]`, inconsistent formatting, etc.

# %% [markdown]
# To simplify the parsing process, we have provided an incomplete code snippet below to help you to fill up the `launch_dict`. Please complete the following code snippet with TODOs or you can choose to write your own logic to parse all launch tables:

# %%
# extracted_row = 0
# #Extract each table 
# for table_number,table in enumerate(soup.find_all('table',"wikitable plainrowheaders collapsible")):
#    # get table row 
#     for rows in table.find_all("tr"):
#         #check to see if first table heading is as number corresponding to launch a number 
#         if rows.th:
#             if rows.th.string:
#                 flight_number=rows.th.string.strip()
#                 flag=flight_number.isdigit()
#         else:
#             flag=False
#         #get table element 
#         row=rows.find_all('td')
#         #if it is number save cells in a dictonary 
#         if flag:
#             extracted_row += 1
#             # Flight Number value
#             # TODO: Append the flight_number into launch_dict with key `Flight No.`
#             #print(flight_number)
#             datatimelist=date_time(row[0])
            
#             # Date value
#             # TODO: Append the date into launch_dict with key `Date`
#             date = datatimelist[0].strip(',')
#             #print(date)
            
#             # Time value
#             # TODO: Append the time into launch_dict with key `Time`
#             time = datatimelist[1]
#             #print(time)
              
#             # Booster version
#             # TODO: Append the bv into launch_dict with key `Version Booster`
#             bv=booster_version(row[1])
#             if not(bv):
#                 bv=row[1].a.string
#             print(bv)
            
#             # Launch Site
#             # TODO: Append the bv into launch_dict with key `Launch Site`
#             launch_site = row[2].a.string
#             #print(launch_site)
            
#             # Payload
#             # TODO: Append the payload into launch_dict with key `Payload`
#             payload = row[3].a.string
#             #print(payload)
            
#             # Payload Mass
#             # TODO: Append the payload_mass into launch_dict with key `Payload mass`
#             payload_mass = get_mass(row[4])
#             #print(payload)
            
#             # Orbit
#             # TODO: Append the orbit into launch_dict with key `Orbit`
#             orbit = row[5].a.string
#             #print(orbit)
            
#             # Customer
#             # TODO: Append the customer into launch_dict with key `Customer`
#             customer = row[6].a.string
#             #print(customer)
            
#             # Launch outcome
#             # TODO: Append the launch_outcome into launch_dict with key `Launch outcome`
#             launch_outcome = list(row[7].strings)[0]
#             #print(launch_outcome)
            
#             # Booster landing
#             # TODO: Append the launch_outcome into launch_dict with key `Booster landing`
#             booster_landing = landing_status(row[8])
#             #print(booster_landing)

# %% [markdown]
# After you have fill in the parsed launch record values into `launch_dict`, you can create a dataframe from it.

# %%
pd.set_option('display.max_rows', None)
df=pd.DataFrame(launch_dict1)
print(df.shape)
df
# Out:
# (121, 11)
#     Flight No.     Launch site                                   Payload  \
# 0            1           CCAFS      Dragon Spacecraft Qualification Unit
# 1            2           CCAFS                                    Dragon
# 2            3           CCAFS                                    Dragon
# 3            4           CCAFS                              SpaceX CRS-1
# 4            5           CCAFS                              SpaceX CRS-2
# 5            6            VAFB                                  CASSIOPE
# 6            7           CCAFS                                     SES-8
# 7            8           CCAFS                                 Thaicom 6
# 8            9  Cape Canaveral                              SpaceX CRS-3
# 9           10  Cape Canaveral                               Orbcomm-OG2
# 10          11  Cape Canaveral                                 AsiaSat 8
# 11          12  Cape Canaveral                                 AsiaSat 6
# 12          13  Cape Canaveral                              SpaceX CRS-4
# 13          14  Cape Canaveral                              SpaceX CRS-5
# 14          15  Cape Canaveral                                    DSCOVR
# 15          16  Cape Canaveral                                    ABS-3A
# 16          17  Cape Canaveral                              SpaceX CRS-6
# 17          18  Cape Canaveral              TürkmenÄlem 52°E / MonacoSAT
# 18          19  Cape Canaveral                              SpaceX CRS-7
# 19          20  Cape Canaveral                               Orbcomm-OG2
# 20          21            VAFB                                   Jason-3
# 21          22  Cape Canaveral                                     SES-9
# 22          23  Cape Canaveral                              SpaceX CRS-8
# 23          24  Cape Canaveral                                  JCSAT-14
# 24          25  Cape Canaveral                                 Thaicom 8
# 25          26  Cape Canaveral                                    ABS-2A
# 26          27  Cape Canaveral                              SpaceX CRS-9
# 27          28  Cape Canaveral                                  JCSAT-16
# 28          29            VAFB                              Iridium NEXT
# 29          30             KSC                             SpaceX CRS-10
# 30          31             KSC                               EchoStar 23
# 31          32             KSC                                    SES-10
# 32          33             KSC                                   NROL-76
# 33          34             KSC                             Inmarsat-5 F4
# 34          35             KSC                             SpaceX CRS-11
# 35          36             KSC                             BulgariaSat-1
# 36          37            VAFB                              Iridium NEXT
# 37          38             KSC                              Intelsat 35e
# 38          39             KSC                             SpaceX CRS-12
# 39          40            VAFB                                Formosat-5
# 40          41             KSC                              Boeing X-37B
# 41          42            VAFB                              Iridium NEXT
# 42          43             KSC                                    SES-11
# 43          44             KSC                               Koreasat 5A
# 44          45  Cape Canaveral                             SpaceX CRS-13
# 45          46            VAFB                              Iridium NEXT
# 46          47           CCAFS                                      Zuma
# 47          48           CCAFS                                  GovSat-1
# 48          49            VAFB                                       Paz
# 49          50           CCAFS                            Hispasat 30W-6
# 50          51            VAFB                              Iridium NEXT
# 51          52           CCAFS                             SpaceX CRS-14
# 52          53           CCAFS     Transiting Exoplanet Survey Satellite
# 53          54             KSC                             Bangabandhu-1
# 54          55            VAFB                              Iridium NEXT
# 55          56           CCAFS                                    SES-12
# 56          57           CCAFS                             SpaceX CRS-15
# 57          58           CCAFS                               Telstar 19V
# 58          59            VAFB                              Iridium NEXT
# 59          60           CCAFS                               Merah Putih
# 60          61           CCAFS                               Telstar 18V
# 61          62            VAFB                                 SAOCOM 1A
# 62          63             KSC                                 Es'hail 2
# 63          64            VAFB                                     SSO-A
# 64          65           CCAFS                             SpaceX CRS-16
# 65          66           CCAFS                                   GPS III
# 66          67            VAFB                              Iridium NEXT
# 67          68           CCAFS                            Nusantara Satu
# 68          69             KSC                        Crew Dragon Demo-1
# 69          70           CCAFS                             SpaceX CRS-17
# 70          71           CCAFS                                  Starlink
# 71          72            VAFB                    RADARSAT Constellation
# 72          73           CCAFS                             SpaceX CRS-18
# 73          74           CCAFS                                   AMOS-17
# 74          75           CCAFS                                  Starlink
# 75          76           CCAFS                             SpaceX CRS-19
# 76          77           CCAFS                                  JCSat-18
# 77          78           CCAFS                                  Starlink
# 78          79             KSC          Crew Dragon in-flight abort test
# 79          80           CCAFS                                  Starlink
# 80          81           CCAFS                                  Starlink
# 81          82           CCAFS                             SpaceX CRS-20
# 82          83             KSC                                  Starlink
# 83          84             KSC                                  Starlink
# 84          85             KSC                        Crew Dragon Demo-2
# 85          86           CCAFS                                  Starlink
# 86          87           CCAFS                                  Starlink
# 87          88           CCAFS                                   GPS III
# 88          89           CCAFS                                 ANASIS-II
# 89          90             KSC                                  Starlink
# 90          91           CCAFS                                  Starlink
# 91          92           CCAFS                                 SAOCOM 1B
# 92          93             KSC                                  Starlink
# 93          94             KSC                                  Starlink
# 94          95             KSC                                  Starlink
# 95          96           CCAFS                                  Starlink
# 96          97           CCAFS                                   GPS III
# 97          98             KSC                                    Crew-1
# 98          99            VAFB  Sentinel-6 Michael Freilich (Jason-CS A)
# 99         100           CCAFS                                  Starlink
# 100        101             KSC                             SpaceX CRS-21
# 101        102           CCSFS                                     SXM-7
# 102        103             KSC                                  NROL-108
# 103        104           CCSFS                                Türksat 5A
# 104        105             KSC                                  Starlink
# 105        106           CCSFS                             Transporter-1
# 106        107           CCSFS                                  Starlink
# 107        108           CCSFS                                  Starlink
# 108        109             KSC                                  Starlink
# 109        110           CCSFS                                  Starlink
# 110        111             KSC                                  Starlink
# 111        112           CCSFS                                  Starlink
# 112        113           CCSFS                                  Starlink
# 113        114             KSC                                    Crew-2
# 114        115           CCSFS                                  Starlink
# 115        116             KSC                                  Starlink
# 116        117           CCSFS                                  Starlink
# 117        118             KSC                                  Starlink
# 118        119           CCSFS                                  Starlink
# 119        120             KSC                             SpaceX CRS-22
# 120        121           CCSFS                                     SXM-8
#
#        Payload mass        Orbit                Customer Launch outcome  \
# 0                 0          LEO                  SpaceX        Success
# 1                 0          LEO                    NASA        Success
# 2            525 kg          LEO                    NASA        Success
# 3          4,700 kg          LEO                    NASA        Success
# 4          4,877 kg          LEO                    NASA        Success
# 5            500 kg  Polar orbit                     MDA        Success
# 6          3,170 kg          GTO                     SES        Success
# 7          3,325 kg          GTO                 Thaicom        Success
# 8          2,296 kg          LEO                    NASA        Success
# 9          1,316 kg          LEO                 Orbcomm        Success
# 10         4,535 kg          GTO                 AsiaSat        Success
# 11         4,428 kg          GTO                 AsiaSat        Success
# 12         2,216 kg          LEO                    NASA        Success
# 13         2,395 kg          LEO                    NASA        Success
# 14           570 kg          HEO                    USAF        Success
# 15         4,159 kg          GTO                     ABS        Success
# 16         1,898 kg          LEO                    NASA        Success
# 17         4,707 kg          GTO                    None        Success
# 18         1,952 kg          LEO                    NASA        Failure
# 19         2,034 kg          LEO                 Orbcomm        Success
# 20           553 kg          LEO                    NASA        Success
# 21         5,271 kg          GTO                     SES        Success
# 22         3,136 kg          LEO                    NASA        Success
# 23         4,696 kg          GTO  SKY Perfect JSAT Group        Success
# 24         3,100 kg          GTO                 Thaicom        Success
# 25         3,600 kg          GTO                     ABS        Success
# 26         2,257 kg          LEO                    NASA        Success
# 27         4,600 kg          GTO  SKY Perfect JSAT Group        Success
# 28         9,600 kg        Polar  Iridium Communications        Success
# 29         2,490 kg          LEO                    NASA        Success
# 30         5,600 kg          GTO                EchoStar        Success
# 31         5,300 kg          GTO                     SES        Success
# 32                C          LEO                     NRO        Success
# 33         6,070 kg          GTO                Inmarsat        Success
# 34         2,708 kg          LEO                    NASA        Success
# 35         3,669 kg          GTO               Bulsatcom        Success
# 36         9,600 kg          LEO  Iridium Communications        Success
# 37         6,761 kg          GTO                Intelsat        Success
# 38         3,310 kg          LEO                    NASA        Success
# 39           475 kg          SSO                    NSPO        Success
# 40         4,990 kg          LEO                    USAF        Success
# 41         9,600 kg        Polar  Iridium Communications        Success
# 42         5,200 kg          GTO                SES S.A.        Success
# 43         3,500 kg          GTO          KT Corporation        Success
# 44         2,205 kg          LEO                    NASA        Success
# 45         9,600 kg        Polar  Iridium Communications        Success
# 46                C          LEO        Northrop Grumman        Success
# 47         4,230 kg          GTO                     SES        Success
# 48         2,150 kg          SSO                Hisdesat        Success
# 49         6,092 kg          GTO                Hispasat        Success
# 50         9,600 kg        Polar  Iridium Communications        Success
# 51         2,647 kg          LEO                    NASA        Success
# 52           362 kg          HEO                    NASA        Success
# 53         3,600 kg          GTO           Thales-Alenia        Success
# 54         6,460 kg        Polar  Iridium Communications        Success
# 55         5,384 kg          GTO                     SES        Success
# 56         2,697 kg          LEO                    NASA        Success
# 57         7,075 kg          GTO                 Telesat        Success
# 58         9,600 kg        Polar  Iridium Communications        Success
# 59         5,800 kg          GTO        Telkom Indonesia        Success
# 60         7,060 kg          GTO                 Telesat        Success
# 61         3,000 kg          SSO                   CONAE        Success
# 62         5,300 kg          GTO              Es'hailSat        Success
# 63        ~4,000 kg          SSO  Spaceflight Industries        Success
# 64         2,500 kg          LEO                    NASA        Success
# 65         4,400 kg          MEO                    USAF        Success
# 66         9,600 kg        Polar  Iridium Communications        Success
# 67         4,850 kg          GTO                     PSN        Success
# 68        12,055 kg          LEO                    NASA        Success
# 69         2,495 kg          LEO                    NASA        Success
# 70        13,620 kg          LEO                  SpaceX        Success
# 71         4,200 kg          SSO   Canadian Space Agency        Success
# 72         2,268 kg          LEO                    NASA        Success
# 73         6,500 kg          GTO                Spacecom        Success
# 74        15,600 kg          LEO                  SpaceX        Success
# 75         2,617 kg          LEO                    NASA        Success
# 76         6,956 kg          GTO        Sky Perfect JSAT        Success
# 77        15,600 kg          LEO                  SpaceX        Success
# 78        12,050 kg  Sub-orbital                    NASA        Success
# 79        15,600 kg          LEO                  SpaceX        Success
# 80        15,600 kg          LEO                  SpaceX        Success
# 81         1,977 kg          LEO                    NASA        Success
# 82        15,600 kg          LEO                  SpaceX        Success
# 83        15,600 kg          LEO                  SpaceX        Success
# 84        12,530 kg          LEO                    NASA        Success
# 85        15,600 kg          LEO                  SpaceX        Success
# 86        15,410 kg          LEO                  SpaceX        Success
# 87         4,311 kg          MEO        U.S. Space Force        Success
# 88   5,000–6,000 kg          GTO  Republic of Korea Army        Success
# 89        14,932 kg          LEO                  SpaceX        Success
# 90       ~15,440 kg          LEO                  SpaceX        Success
# 91         3,130 kg          SSO                   CONAE        Success
# 92        15,600 kg          LEO                  SpaceX        Success
# 93        15,600 kg          LEO                  SpaceX        Success
# 94        15,600 kg          LEO                  SpaceX        Success
# 95        15,600 kg          LEO                  SpaceX        Success
# 96         4,311 kg          MEO                    USSF        Success
# 97       ~12,500 kg          LEO                    NASA        Success
# 98         1,192 kg          LEO                    NASA        Success
# 99        15,600 kg          LEO                  SpaceX        Success
# 100        2,972 kg          LEO                    NASA        Success
# 101        7,000 kg          GTO               Sirius XM        Success
# 102               C          LEO                     NRO        Success
# 103        3,500 kg          GTO                 Türksat        Success
# 104       15,600 kg          LEO                  SpaceX        Success
# 105       ~5,000 kg          SSO                    None        Success
# 106       15,600 kg          LEO                  SpaceX        Success
# 107       15,600 kg          LEO                  SpaceX        Success
# 108       15,600 kg          LEO                  SpaceX        Success
# 109       15,600 kg          LEO                  SpaceX        Success
# 110       15,600 kg          LEO                  SpaceX        Success
# 111       15,600 kg          LEO                  SpaceX        Success
# 112       15,600 kg          LEO                  SpaceX        Success
# 113      ~13,000 kg          LEO                    NASA        Success
# 114       15,600 kg          LEO                  SpaceX        Success
# 115       15,600 kg          LEO                  SpaceX        Success
# 116       15,600 kg          LEO                  SpaceX        Success
# 117      ~14,000 kg          LEO                  SpaceX        Success
# 118       15,600 kg          LEO                  SpaceX        Success
# 119        3,328 kg          LEO                    NASA        Success
# 120        7,000 kg          GTO               Sirius XM        Success
#
#     Version Booster Booster landing               Date      Time
# 0    F9 v1.0B0003.1         Failure        4 June 2010     18:45
# 1    F9 v1.0B0004.1         Failure    8 December 2010     15:43
# 2    F9 v1.0B0005.1      No attempt        22 May 2012     07:44
# 3    F9 v1.0B0006.1      No attempt     8 October 2012     00:35
# 4    F9 v1.0B0007.1      No attempt       1 March 2013     15:10
# 5      F9 v1.1B1003    Uncontrolled  29 September 2013     16:00
# 6           F9 v1.1      No attempt    3 December 2013     22:41
# 7           F9 v1.1      No attempt     6 January 2014     22:06
# 8           F9 v1.1      Controlled      18 April 2014     19:25
# 9           F9 v1.1      Controlled       14 July 2014     15:15
# 10          F9 v1.1      No attempt      5 August 2014     08:00
# 11          F9 v1.1      No attempt   7 September 2014     05:00
# 12          F9 v1.1    Uncontrolled  21 September 2014     05:52
# 13          F9 v1.1        Failure     10 January 2015     09:47
# 14          F9 v1.1      Controlled   11 February 2015     23:03
# 15          F9 v1.1      No attempt       2 March 2015     03:50
# 16          F9 v1.1         Failure      14 April 2015     20:10
# 17          F9 v1.1      No attempt      27 April 2015     23:03
# 18          F9 v1.1       Precluded       28 June 2015     14:21
# 19            F9 FT         Success   22 December 2015     01:29
# 20          F9 v1.1         Failure    17 January 2016     18:42
# 21            F9 FT         Failure       4 March 2016     23:35
# 22            F9 FT         Success       8 April 2016     20:43
# 23            F9 FT         Success         6 May 2016     05:21
# 24            F9 FT         Success        27 May 2016     21:39
# 25            F9 FT         Failure       15 June 2016     14:29
# 26            F9 FT         Success       18 July 2016     04:45
# 27            F9 FT         Success     14 August 2016     05:26
# 28            F9 FT         Success    14 January 2017     17:54
# 29            F9 FT         Success   19 February 2017     14:39
# 30            F9 FT      No attempt      16 March 2017     06:00
# 31           F9 FT♺         Success      30 March 2017     22:27
# 32            F9 FT         Success         1 May 2017     11:15
# 33            F9 FT      No attempt        15 May 2017     23:21
# 34            F9 FT         Success        3 June 2017     21:07
# 35     F9 FTB1029.2         Success       23 June 2017     19:10
# 36            F9 FT         Success       25 June 2017     20:25
# 37            F9 FT      No attempt        5 July 2017     23:38
# 38            F9 B4         Success     14 August 2017     16:31
# 39            F9 FT         Success     24 August 2017     18:51
# 40            F9 B4         Success   7 September 2017     14:00
# 41            F9 B4         Success     9 October 2017     12:37
# 42     F9 FTB1031.2         Success    11 October 2017  22:53:00
# 43            F9 B4         Success    30 October 2017     19:34
# 44     F9 FTB1035.2         Success   15 December 2017     15:36
# 45     F9 FTB1036.2      Controlled   23 December 2017     01:27
# 46            F9 B4         Success     8 January 2018     01:00
# 47     F9 FTB1032.2      Controlled    31 January 2018     21:25
# 48     F9 FTB1038.2      No attempt   22 February 2018     14:17
# 49            F9 B4      No attempt       6 March 2018     05:33
# 50     F9 B4B1041.2      No attempt      30 March 2018     14:14
# 51     F9 B4B1039.2      No attempt       2 April 2018     20:30
# 52            F9 B4         Success      18 April 2018     22:51
# 53     F9 B5B1046.1         Success        11 May 2018     20:14
# 54     F9 B4B1043.2      No attempt        22 May 2018     19:47
# 55     F9 B4B1040.2      No attempt        4 June 2018     04:45
# 56     F9 B4B1045.2      No attempt       29 June 2018     09:42
# 57            F9 B5         Success       22 July 2018     05:50
# 58       F9 B5B1048         Success       25 July 2018     11:39
# 59     F9 B5B1046.2         Success      7 August 2018     05:18
# 60            F9 B5         Success  10 September 2018     04:45
# 61     F9 B5B1048.2         Success     8 October 2018     02:22
# 62     F9 B5B1047.2         Success   15 November 2018     20:46
# 63     F9 B5B1046.3         Success    3 December 2018  18:34:05
# 64            F9 B5         Failure    5 December 2018     18:16
# 65            F9 B5      No attempt   23 December 2018     13:51
# 66     F9 B5B1049.2         Success    11 January 2019     15:31
# 67     F9 B5B1048.3         Success   22 February 2019     01:45
# 68       F9 B5[268]         Success       2 March 2019     07:49
# 69            F9 B5         Success         4 May 2019     06:48
# 70     F9 B5B1049.3         Success        24 May 2019     02:30
# 71     F9 B5B1051.2         Success       12 June 2019     14:17
# 72     F9 B5B1056.2         Success       25 July 2019     22:01
# 73     F9 B5B1047.3      No attempt      6 August 2019     23:23
# 74            F9 B5         Success   11 November 2019     14:56
# 75            F9 B5         Success    5 December 2019     17:29
# 76     F9 B5B1056.3         Success   17 December 2019     00:10
# 77            F9 B5         Success     7 January 2020  02:19:21
# 78            F9 B5      No attempt    19 January 2020     15:30
# 79            F9 B5         Success    29 January 2020     14:07
# 80            F9 B5         Failure   17 February 2020     15:05
# 81            F9 B5         Success       7 March 2020     04:50
# 82            F9 B5         Failure      18 March 2020     12:16
# 83            F9 B5         Success      22 April 2020     19:30
# 84            F9 B5         Success        30 May 2020     19:22
# 85            F9 B5         Success        4 June 2020     01:25
# 86            F9 B5         Success       13 June 2020     09:21
# 87            F9 B5         Success       30 June 2020  20:10:46
# 88     F9 B5B1058.2         Success       20 July 2020     21:30
# 89            F9 B5         Success      7 August 2020     05:12
# 90     F9 B5B1049.6         Success     18 August 2020     14:31
# 91            F9 B5         Success     30 August 2020     23:18
# 92     F9 B5B1060.2         Success   3 September 2020  12:46:14
# 93     F9 B5B1058.3         Success     6 October 2020  11:29:34
# 94     F9 B5B1051.6         Success    18 October 2020  12:25:57
# 95            F9 B5         Success    24 October 2020  15:31:34
# 96            F9 B5         Success    5 November 2020  23:24:23
# 97            F9 B5         Success   16 November 2020     00:27
# 98            F9 B5         Success   21 November 2020  17:17:08
# 99          F9 B5 ♺         Success   25 November 2020     02:13
# 100         F9 B5 ♺         Success    6 December 2020  16:17:08
# 101         F9 B5 ♺         Success   13 December 2020  17:30:00
# 102         F9 B5 ♺         Success   19 December 2020  14:00:00
# 103           F9 B5         Success     8 January 2021     02:15
# 104    F9 B5B1051.8         Success    20 January 2021     13:02
# 105    F9 B5B1058.5         Success    24 January 2021     15:00
# 106         F9 B5 ♺         Success    4 February 2021     06:19
# 107         F9 B5 ♺         Failure   16 February 2021  03:59:37
# 108         F9 B5 ♺         Success       4 March 2021     08:24
# 109         F9 B5 ♺         Success      11 March 2021  08:13:29
# 110         F9 B5 ♺         Success      14 March 2021     10:01
# 111    F9 B5B1060.6         Success      24 March 2021     08:28
# 112         F9 B5 ♺         Success       7 April 2021     16:34
# 113    F9 B5B1061.2         Success      23 April 2021      9:49
# 114    F9 B5B1060.7         Success      29 April 2021     03:44
# 115    F9 B5B1049.9         Success         4 May 2021     19:01
# 116   F9 B5B1051.10         Success         9 May 2021     06:42
# 117    F9 B5B1058.8         Success        15 May 2021     22:56
# 118    F9 B5B1063.2         Success        26 May 2021     18:59
# 119    F9 B5B1067.1         Success        3 June 2021     17:29
# 120           F9 B5         Success        6 June 2021     04:26

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section, but to make the answers consistent and in case you have difficulties finishing this lab.
#
# Following labs will be using a provided dataset to make each lab independent.

# %%
project.save_data(data=df.to_csv(index=False), file_name='spacex_web_scraped.csv', overwrite=True)
# Out:
# {'file_name': 'spacex_web_scraped.csv',
#  'message': 'File saved to project storage.',
#  'bucket_name': 'applieddatasciencecapstone-donotdelete-pr-jx5un88ldtszdu',
#  'asset_id': 'c631450f-bb56-4815-9385-21791ad86f87'}

# %% [markdown]
# BOOBS!!!

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01">Yan Luo</a>

# %% [markdown]
# <a href="https://www.linkedin.com/in/nayefaboutayoun/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01">Nayef Abou Tayoun</a>

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description          |
# | ----------------- | ------- | ---------- | --------------------------- |
# | 2021-06-09        | 1.0     | Yan Luo    | Tasks updates               |
# | 2020-11-10        | 1.0     | Nayef      | Created the initial version |

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
